# %% [markdown]
# # 1. Background Information

# %% [markdown]
# # 2. Explanatory Data Analysis

# %%
# Import packages
import numpy as np
import pandas as pd
import os
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
import dexplot as dxp

# %%
# Load data
sleep = pd.read_excel("2015SleepinAmericaPollSleepandPainRawDataExcel.xlsx")

# %% [markdown]
# ## 2.1 Variable Construction & Data Cleaning

# %%
## Variable Construction
# average sleep hours per day
sleep['avg_sleep'] = (sleep.DOV_WEEKTIME/ 60 * 5 + sleep.DOV_WEEKEND / 60 * 2)/ 7
# average actual sleep per day
sleep['avg_actual_sleep'] = (sleep.DOV_TOTALWEEK/ 60 * 5 + sleep.DOV_TOTALWEEKEND / 60 * 2)/ 7
# Define sleep efficiency as average actual sleep per day/average sleep hours per day
sleep['sleep_efficiency'] = sleep.avg_actual_sleep/sleep.avg_sleep

# Whether the person go to bed before or after mid-night on weekdays
sleep['before_mnt_week'] = 'Before Mid-night'
sleep.before_mnt_week.loc[sleep.Q2_ampmA == 1] = 'After Mid-night'

# Whether the person go to bed before or after mid-night on weekends
sleep['before_mnt_weekend'] = 'Before Mid-night'
sleep.before_mnt_weekend.loc[sleep.Q3_ampmA == 1] = 'After Mid-night'

## Data Cleaning
# Sleep efficiency <= 1
sleep_eff = sleep.loc[sleep.sleep_efficiency <= 1]
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# ## 2.2 Individual Variables

# %% [markdown]
# ### 2.2.1 Sleep Quality

# %%
sns.countplot(x="Q10_a", data=sleep)
plt.xlabel('Sleep Quality')
# Out:
# Text(0.5, 0, 'Sleep Quality')

# %% [markdown]
# ### 2.2.1 Sleep Efficiency

# %%
sns.distplot(sleep_eff.sleep_efficiency, 
             hist = True, kde = True,
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 3})

plt.xlabel('Sleep Efficiency')
# Out:
# Text(0.5, 0, 'Sleep Efficiency')

# %% [markdown]
# ## 2.3 Relationship between Variables

# %% [markdown]
# ### 2.3.1 Time Go to Bed & Sleep Quality

# %%
# Weekdays
bar_data_week = sleep.groupby('before_mnt_week').Q10_a.value_counts(normalize=True).unstack().T
bar_data_week.plot.bar(rot=0, title = 'Sleep Quality on Weekdays')
plt.legend(handles = None)
plt.xlabel('Sleep Quality')
plt.ylabel('Percentage')


# Weekdays
bar_data_weekend = sleep.groupby('before_mnt_weekend').Q10_a.value_counts(normalize=True).unstack().T
bar_data_weekend.plot.bar(rot=0, title = 'Sleep Quality on Weekends')
plt.legend(handles = None)
plt.xlabel('Sleep Quality')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# ### 2.3.2 Time Go to Bed & Sleep Efficiency

# %%
# Weekdays
sns.distplot(sleep_eff.sleep_efficiency.loc[sleep_eff.before_mnt_week == 'Before Mid-night'], label = 'Before Mid-night', hist = False, kde=True, 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 3, "shade": True})

sns.distplot(sleep_eff.sleep_efficiency.loc[sleep_eff.before_mnt_week == 'After Mid-night'], label = 'After Mid-night', hist = False, kde=True, 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 3, "shade": True})
plt.title('Sleep Quality on Weekdays')
plt.legend(loc = 'upper left')
plt.xlabel('Sleep Efficiency')
# Out:
# Text(0.5, 0, 'Sleep Efficiency')

# %%
# Weekends
sns.distplot(sleep_eff.sleep_efficiency.loc[sleep_eff.before_mnt_weekend == 'Before Mid-night'], label = 'Before Mid-night', hist = False, kde=True, 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 3, "shade": True})

sns.distplot(sleep_eff.sleep_efficiency.loc[sleep_eff.before_mnt_weekend == 'After Mid-night'], label = 'After Mid-night', hist = False, kde=True, 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 3, "shade": True})
plt.title('Sleep Quality on Weekends')
plt.legend(loc = 'upper left')
plt.xlabel('Sleep Efficiency')
# Out:
# Text(0.5, 0, 'Sleep Efficiency')

# %% [markdown]
# ### 2.3.3 Sleep Efficiency & Sleep Quality

# %%
for i in range(1,6): 
    sns.distplot(sleep_eff.sleep_efficiency.loc[sleep_eff.Q10_a == i], label = 'sleep quality = ' + str(i), hist = False, kde=True, 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 3})
plt.legend()

# %%
# Number of people with sleeping efficiency < 0.8
sleep.loc[sleep.sleep_efficiency < 0.8].shape
# Out:
# (232, 196)
